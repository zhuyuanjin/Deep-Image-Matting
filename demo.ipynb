# %%
from train import *

# %%
import torch

# %%
torch.optim.

# %%
import PIL.Image as Image
import matplotlib.pyplot as plt

# %%
data = dataset[100]

# %%
plt.imshow(data['img'].transpose([1,2,0]))

# %%
plt.imshow(data['alpha'].squeeze(0), cmap='gray')

# %%
plt.imshow(data['trimap'].squeeze(0), cmap='gray')

# %%
plt.imshow(data['unknown'].squeeze(0), cmap='gray')

# %%
Image.open('/home/zhuyuanjin/data/Human_Matting/image/1803151818-00000003.jpg').size
# Out:
# (600, 800)

# %%
data['img'].shape
# Out:
# (3, 320, 320)
